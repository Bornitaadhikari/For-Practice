# %% [markdown]
# <a href="https://colab.research.google.com/github/Bornitaadhikari/For-Practice/blob/main/Removing_Outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data= {
    "Name":["Rob","Borni","Raha","Rabi","Savu","Hasi","Guya","Iavo"],
    "Income":[8000,1000,3000,5000,6000,4000,5000,6000000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Income
# 0    Rob     8000
# 1  Borni     1000
# 2   Raha     3000
# 3   Rabi     5000
# 4   Savu     6000
# 5   Hasi     4000
# 6   Guya     5000
# 7   Iavo  6000000

# %%
df.Income.quantile(0.75)
# Out:
# 6500.0

# %%
df.Income.quantile(0.75,interpolation="higher")
# Out:
# 8000

# %%
df.Income.quantile(0.75,interpolation="lower")
# Out:
# 6000

# %%
percentile_99=df.Income.quantile(.99)
percentile_99
# Out:
# 5580559.999999998

# %%
df_no_outlier= df[df.Income>percentile_99]
df_no_outlier
# Out:
#    Name   Income
# 7  Iavo  6000000

# %%
import pandas as pd

df = pd.read_csv('/content/AB_NYC_2019.csv')
df.head()
# Out:
#          id                                               name    host_id  \
# 0  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 1  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 2  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 3  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 4  20624541      Modern apartment in the heart of Williamsburg   10132166
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0      Kimberly            Brooklyn  Bedford-Stuyvesant  40.69023  -73.95428
# 1        Anisha               Bronx     East Morrisania  40.83296  -73.88668
# 2  Martial Loft            Brooklyn            Bushwick  40.69467  -73.92433
# 3        Lauren            Brooklyn          Greenpoint  40.72462  -73.94072
# 4       Aymeric            Brooklyn        Williamsburg  40.70838  -73.94645
#
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
percentile_25 =  df.price.quantile(0.25)
percentile_25
# Out:
# 69.0

# %%
percentile_50=df.price.quantile(0.50)
percentile_50
# Out:
# 106.0

# %%
percentile_75=df.price.quantile(0.75)
percentile_75
# Out:
# 175.0

# %%
# Assuming 'price' is the column in your DataFrame
percentile_25 = df['price'].quantile(0.25)
percentile_75 = df['price'].quantile(0.99)

df_no_outlier = df[(df['price'] >= percentile_25) & (df['price'] <= percentile_75)]

# %%
df_no_outlier
# Out:
#              id                                               name    host_id  \
# 11999     15220                Best Location in NYC! TIMES SQUARE!      59734
# 12000     36647                Private Bdrm/Bathrm. New! Elevator!     157798
# 12001     39282                   Indie-Chic Share In Williamsburg     168525
# 12002     55959            Spacious Williamsburg Share w/ LOFT BED     168525
# 12003     75193  BROOKLYN > Guest Room w/ King Bed in Williamsburg     308875
# ...         ...                                                ...        ...
# 48416  28715332                 TRIBECA/SOHO 2 BEDROOM LUXURY LOFT  122323589
# 48417  31916725  EMPIRE ST VIEW>Luxury 3BR 2BA BALCONY High fl>Gym  129079212
# 48418  32123225  Top Luxury 3BR 2BA Balcony ->Gym City& River V...   65929049
# 48419  33519952    Class, Comfort, Convenience In The Heart of NYC  229489983
# 48420  34836737                 Spacious Harlem Home in Manhattan!    9486614
#
# ...

# %%
df_no_outlier.price.describe()
# Out:
# count    36422.000000
# mean       166.347729
# std        104.558995
# min         69.000000
# 25%         98.000000
# 50%        135.000000
# 75%        200.000000
# max        799.000000
# Name: price, dtype: float64
